# %% [markdown]
# <center>Task 4</center>
# <center>Task 1 - Analysis on ML Test Scores</center>
# <center>Data Science and Generative AI Internship</center>
# <center>Innomatics Research Labs</center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("scores_data.csv")
df
# Out:
#          Batch  User_ID     Score
# 0    AI_ELITE_7  uid_149       6 / 7
# 1    AI_ELITE_7  uid_148       6 / 7
# 2    AI_ELITE_7  uid_147       7 / 7
# 3    AI_ELITE_7  uid_146       7 / 7
# 4    AI_ELITE_7  uid_145       4 / 7
# ..          ...      ...         ...
# 144  AI_ELITE_4    uid_5       4 / 7
# 145  AI_ELITE_4    uid_4       4 / 7
# 146  AI_ELITE_4    uid_3       4 / 7
# 147  AI_ELITE_4    uid_2       3 / 7
# 148  AI_ELITE_4    uid_1       2 / 7
#
# [149 rows x 3 columns]

# %%
df.shape
# Out:
# (149, 3)

# %%
df.isnull().sum()
# Out:
# Batch          0
# User_ID        0
#    Score       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Batch ', 'User_ID ', '   Score   '], dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Batch', 'User_ID', 'Score'], dtype='object')

# %%
df.dtypes
# Out:
# Batch      object
# User_ID    object
# Score      object
# dtype: object

# %%
df['Marks'] = df['Score'].str.split("/").str[0]

# %%
df['Marks'] = df['Marks'].astype(int)

# %%
df
# Out:
#           Batch  User_ID  Score  Marks
# 0    AI_ELITE_7  uid_149  6 / 7      6
# 1    AI_ELITE_7  uid_148  6 / 7      6
# 2    AI_ELITE_7  uid_147  7 / 7      7
# 3    AI_ELITE_7  uid_146  7 / 7      7
# 4    AI_ELITE_7  uid_145  4 / 7      4
# ..          ...      ...    ...    ...
# 144  AI_ELITE_4    uid_5  4 / 7      4
# 145  AI_ELITE_4    uid_4  4 / 7      4
# 146  AI_ELITE_4    uid_3  4 / 7      4
# 147  AI_ELITE_4    uid_2  3 / 7      3
# 148  AI_ELITE_4    uid_1  2 / 7      2
#
# [149 rows x 4 columns]

# %%
avg = df.groupby('Batch')['Marks'].mean().reset_index()
avg
# Out:
#         Batch     Marks
# 0  AI_ELITE_4  3.791667
# 1  AI_ELITE_6  4.229167
# 2  AI_ELITE_7  5.056604

# %%
med = df.groupby('Batch')['Marks'].median().reset_index()
med
# Out:
#         Batch  Marks
# 0  AI_ELITE_4    4.0
# 1  AI_ELITE_6    4.0
# 2  AI_ELITE_7    5.0

# %%
hig = df.groupby('Batch')['Marks'].max().reset_index()
hig
# Out:
#         Batch  Marks
# 0  AI_ELITE_4      7
# 1  AI_ELITE_6      7
# 2  AI_ELITE_7      7

# %%
low = df.groupby('Batch')['Marks'].min().reset_index()
low
# Out:
#         Batch  Marks
# 0  AI_ELITE_4      0
# 1  AI_ELITE_6      0
# 2  AI_ELITE_7      2

# %%
b4 = df[df['Batch'] == 'AI_ELITE_4']
b6 = df[df['Batch'] == 'AI_ELITE_6']
b7 = df[df['Batch'] == 'AI_ELITE_7']

# %%
b4.boxplot(column='Marks')
# Out:
# <Axes: >

# %%
b6.boxplot(column='Marks')
# Out:
# <Axes: >

# %%
b7.boxplot(column='Marks')
# Out:
# <Axes: >

# %%
counts = df['Batch'].value_counts()
print(counts)
# Out:
# Batch
# AI_ELITE_7    53
# AI_ELITE_6    48
# AI_ELITE_4    48
# Name: count, dtype: int64

# %%
df['Batch'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Marks'].value_counts().plot(kind='bar')
plt.show()

# %%
b4['Marks'].value_counts().plot(kind='bar')
plt.show()

# %%
b6['Marks'].value_counts().plot(kind='bar')
plt.show()

# %%
b7['Marks'].value_counts()
# Out:
# Marks
# 6    13
# 5    11
# 7    10
# 4    10
# 3     7
# 2     2
# Name: count, dtype: int64

# %%
df[df['Marks'] == 7]
# Out:
#           Batch  User_ID  Score  Marks
# 2    AI_ELITE_7  uid_147  7 / 7      7
# 3    AI_ELITE_7  uid_146  7 / 7      7
# 5    AI_ELITE_7  uid_144  7 / 7      7
# 7    AI_ELITE_7  uid_142  7 / 7      7
# 15   AI_ELITE_7  uid_134  7 / 7      7
# 16   AI_ELITE_7  uid_133  7 / 7      7
# 17   AI_ELITE_7  uid_132  7 / 7      7
# 19   AI_ELITE_7  uid_130  7 / 7      7
# 24   AI_ELITE_7  uid_125  7 / 7      7
# 35   AI_ELITE_7  uid_114  7 / 7      7
# 63   AI_ELITE_6   uid_86  7 / 7      7
# 67   AI_ELITE_6   uid_82  7 / 7      7
# 74   AI_ELITE_6   uid_75  7 / 7      7
# 78   AI_ELITE_6   uid_71  7 / 7      7
# 98   AI_ELITE_6   uid_51  7 / 7      7
# 101  AI_ELITE_4   uid_48  7 / 7      7
# 105  AI_ELITE_4   uid_44  7 / 7      7
# 139  AI_ELITE_4   uid_10  7 / 7      7

# %%
df[df['Marks'] == 0]
# Out:
#           Batch User_ID  Score  Marks
# 68   AI_ELITE_6  uid_81  0 / 7      0
# 135  AI_ELITE_4  uid_14  0 / 7      0

# %%
df[df['Marks'] == 2]
# Out:
#           Batch  User_ID  Score  Marks
# 37   AI_ELITE_7  uid_112  2 / 7      2
# 50   AI_ELITE_7   uid_99  2 / 7      2
# 92   AI_ELITE_6   uid_57  2 / 7      2
# 93   AI_ELITE_6   uid_56  2 / 7      2
# 95   AI_ELITE_6   uid_54  2 / 7      2
# 108  AI_ELITE_4   uid_41  2 / 7      2
# 109  AI_ELITE_4   uid_40  2 / 7      2
# 111  AI_ELITE_4   uid_38  2 / 7      2
# 113  AI_ELITE_4   uid_36  2 / 7      2
# 114  AI_ELITE_4   uid_35  2 / 7      2
# 116  AI_ELITE_4   uid_33  2 / 7      2
# 148  AI_ELITE_4    uid_1  2 / 7      2

# %%
plt.hist(b4['Marks'], bins=range(0, 8))
# Out:
# (array([ 1.,  1.,  7.,  8., 19.,  8.,  4.]),
#  array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(b6['Marks'], bins=range(0, 8))
# Out:
# (array([ 1.,  2.,  3.,  9., 11., 13.,  9.]),
#  array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(b7['Marks'], bins=range(0, 8))
# Out:
# (array([ 0.,  0.,  2.,  7., 10., 11., 23.]),
#  array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 7 artists>)

# %% [markdown]
# Conclusion: There are a total of 149 students divided into three batches: AI_ELITE_4, AI_ELITE_6, and AI_ELITE_7, with 53, 48, and 48 students respectively. The maximum mark for each batch is 7, while the minimum marks are 0 for AI_ELITE_4 and AI_ELITE_6, and 2 for AI_ELITE_7. The mean scores for the batches are 3.8, 4.2, and 5.0, respectively, with medians of 4, 4, and 5. Notably, there are three outliers in the AI_ELITE_4 batch, whereas the other two batches have no outliers. In AI_ELITE_4, the majority of students scored 4 marks (about 19 students), with one student scoring the minimum of 0 and three students scoring the maximum of 7. In AI_ELITE_6, 13 students scored 5 marks, while one student achieved the lowest score and five students secured the highest mark. For AI_ELITE_7, no student scored 0; the highest mark of 7 was achieved by 10 students, and the lowest mark of 2 was scored by 2 students. Overall, the most common score across all batches is 4, while the lowest score observed is 0.
